# %% [markdown]
# <a href="https://colab.research.google.com/github/daro/Ahmsville-Dial-App/blob/master/Copy_of_j4yb35_assessment_without_answers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # J4YB35 - Programming for Data
# **LO1 LO2 LO3 & LO4 Assessment**
#
# You have been hired as a Data Scientist by a Further Education College to perform analysis of their student attainment data. Your first task will be to predict student grades from various characteristics, followed by a second task to predict their marks based on their attendance.

# %% [markdown]
# # Assessment Conditions

# %% [markdown]
# This evidence may be produced over the life of the unit, under loosely controlled conditions
# (including access to reference materials). As the evidence is produced in loosely controlled
# conditions it will be authenticated.

# %% [markdown]
# # Learning Outcomes

# %% [markdown]
# See the [J4YB35 Unit Descriptor](https://www.sqa.org.uk/sqa/files/hn/J4YB35.pdf) for further details.
#
# *Outcome 1*
# * Describe the processes and technologies used in a data programming environment.
# * Software types for data analysis
# * High level programming languages for data analysis including functional languages
# * Database languages including SQL
# * Low code software development tools including notebooks
# * Integrated Development Environments
# * Command Line Interfaces
# * Application Programming Interfaces
# * Software libraries
# * Programming process
# * Source/version control
#
# *Outcome 2*
#
# * Explain the concepts, processes and practices used to create clean, efficient code for data analysis.
# * Setting up a project including software installation
# * Programming techniques
# * Data sources
# * Data types and data structures
# * Library functions for data analysis
# * Data interfaces and data flow
# * Data modelling
# * Data security/secret management
# * Code reuse
# * Algorithmic bias and data bias
#
#
# *Outcome 3*
#
# Write functions and programs to perform data analysis.
# * Writing function/program to process data from an external file
# * Writing function/program to process data from a database
# * Writing function/program to clean data
# * Writing function/program to wrangle data
# * Writing function/program to perform statistical analysis
# * Writing function/program to create visualisations
# * Writing documentation for function/program
#
# *Outcome 4*
#
# Test programs for data analysis.
#
# * Test plans
# * Testing datasets
# * Training datasets
# * Debugging
# * Code review
# * Performing test and revising code

# %% [markdown]
# # Task One
# For this first task you are required to describe the general principles of data programming. In addition, you are required to load a SQLite dataset and explain the ethical implications of using it to predict student grades.

# %% [markdown]
# 1. Describe the general development process you will be using. Including how will you perform version control. The libraries and APIs you will be using in your Colab Python notebook.

# %% [markdown]
# In project I willl follow basic analysis process :
#
# 1. Load data from SQLite given file
# 2. Clean data (remove rows with missing values and fix incorect data typess)
# 3. Data exploration and analysis, where I check distributions and relationships between data
# 4. Create simple model to predict student grades based on data sample
#
# For version control, I am using Git and GitHub to track changes, making commits every time I make important changes.
#
# In this project I will use Google Colab notebook as development environment. Main programming language is Python. Libraries which I will use include:
#
# * pandas for data manipulation
# * numpy for numerical operations
# * sqlite3 to connect database

# %% [markdown]
# 2. Describe the technologies used in a data programming environment. Including languages such as Python, R and SQL; data formats such as CSV, JSON and SQL; and tools such as IDEs, command line interfaces and notebooks.

# %% [markdown]
# Python is one of the most popular programming languages used for data analysis. It is free and has many useful libraries.
#
# SQL is used to work with databases. It allows to read, add, update and delete data stored in SQL databases like Oracle, MySQL, PostgreSQL, SQLite, Microsoft SQL Server.
#
# Data is usually stored in SQL databases or in files like CSV or JSON.
# CSV is a simple file format where data is stored in rows and columns, separated by commas. It is often used for spreadsheets and datasets.
#
# JSON is a format used to store data in a structured way using key-value pairs. It is often used in web applications and APIs.
#
# For development, we can use IDEs like PyCharm or Visual Studio Code. Command Line Interface (CLI) is used to run commands in the terminal. Notebooks like Jupyter or Google Colab are also useful because they combine code and results in one place.

# %% [markdown]
# 3. Download this [SQLite file](https://drive.google.com/file/d/1NAfRdd2mOfcZZpbXcf59Q80reVkzHQfU/view?usp=sharing) and upload into /content/sample_data file on notebook
# 4. Document all code using comments to explain your process.
# 5. Read this file into a Pandas dataframe

# %%
# Import nessesery lib
import sqlite3
import pandas as pd

# Connect to the SQLite database using sqlite3
dataConnetion = sqlite3.connect('sample_data/grades.sqlite')

# Load the students table into a df
df = pd.read_sql_query('SELECT * FROM students', dataConnetion)
# Clouse data connection don't need any more
dataConnetion.close()

df.head()
# Out:
#    id      title first_name last_name  house_number         street      town  \
# 0   1  Honorable   Katuscha   Rabjohn          7501     Delladonna   Paisley
# 1   2         Dr       Bald   Winsper             3          Maple   Paisley
# 2   3        Rev   Charmane   Bilyard           400  Meadow Valley  Stirling
# 3   4         Mr       Jany   Schwant            38        Waxwing   Glasgow
# 4   5  Honorable    Valerye  Readwing            29       Dovetail  Stirling
#
#     postcode  gender socio_economic_class  ethnicity grade
# 0     501018  Female                    A   Peruvian     A
# 1      34665    Male                   C1      Cuban     C
# 2  88160-000  Female                    E  Menominee     A
# 3       6118  Female                    A  Cambodian     A
# 4       None  Female                    E     Lumbee     A

# %% [markdown]
# 6. Explain any potential data privacy and security considerations around using and storing this data

# %% [markdown]
# These data contain potentially sensitive information such as the student’s first name, last name, address, and gender.
# This information can be used to identify an individual; however, it is not required for this project and therefore should be removed to ensure compliance with UK GDPR.

# %% [markdown]
# 7. Explain any potential issues around algorithmic bias and data bias with this dataset. Explain if it is ethical to continue using this dataset to make student grade predictions.

# %% [markdown]
# I thing this data not good for this project bevouse contein date

# %% [markdown]
# # Task Two
# You have been assigned a new task after raising the ethical issues with the previous.
#
# For this second task you are required to make student mark predictions based on their attendance. You will create a linear regression model that learns from the previous years marks and attendance data.

# %% [markdown]
# 1. Download this [CSV file](https://drive.google.com/file/d/1Msh1rV1XK0jfsPs8zDyz91rAYGJbw_5n/view?usp=sharing) and upload into /content/sample_data on notebook
# 2. Document all code using comments to explain your process.
# 3. Read the previous years file into a pandas dataframe

# %%
# Import lib
import pandas as pd
import numpy as np

# Load previous year's attendance and marks data
df_prev = pd.read_csv('sample_data/previous_marks_vs_attendance.csv')

print(f'Shape: {df_prev.shape}')
# test data
df_prev.head()
# Out:
# Shape: (28, 2)
#    mark  attendance
# 0  75.0       100.0
# 1  72.0         NaN
# 2  86.0       100.0
# 3  41.0        54.0
# 4  54.0        63.0

# %% [markdown]
# 4. Explore the dataset statistically using pandas and visually using matplotlib

# %%
# Statistical summary
print('=== Descriptive Statistics ===')
print(df_prev.describe())

print('\n=== Null Values ===')
print(df_prev.isnull().sum())

print('\n=== Correlation ===')
print(df_prev.corr())
# Out:
# === Descriptive Statistics ===
#              mark  attendance
# count   27.000000   27.000000
# mean    62.148148   73.962963
# std     26.055715   27.026314
# min     10.000000   20.000000
# 25%     42.500000   55.500000
# 50%     71.000000   75.000000
# 75%     79.500000   99.000000
# max    100.000000  100.000000
#
# === Null Values ===
# mark          1
# attendance    1
# dtype: int64
#
# === Correlation ===
#                 mark  attendance
# mark        1.000000    0.801744
# attendance  0.801744    1.000000

# %% [markdown]
# 5. Perform data cleaning and wrangling including outlier and null removal

# %% [markdown]
# 6. Detail your plan for training and testing a linear regression model on the dataset

# %% [markdown]
# 7. Train and test sklearns linear regression model on the dataset

# %% [markdown]
# 8. Use the linear regression model to predict the mark for a student with 70% attendance

# %% [markdown]
# 9. Detail any debugging, code reviewing and/or revision you have done
